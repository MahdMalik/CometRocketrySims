# %%
from datetime import datetime
from time import process_time, time
import pandas as pd
from rocketpy import Environment, SolidMotor, Rocket, Flight
import concurrent.futures
from ConcurrentFunctions import runFlightWithMonteCarlo
from rocketpy.motors import motor
from IPython.display import display
from scipy.stats import norm
from rocketpy.mathutils.function import Function
from rocketpy.environment import environment

#Calculate and plot landing elipses
# Import libraries
from imageio import imread
from matplotlib.patches import Ellipse

import FlightParams

# %config InlineBackend.figure_formats = ['svg']
import matplotlib as mpl
import matplotlib.pyplot as plt

from wind import getAverageWindPerWeekFromHour, makeWind

# %matplotlib inline
mpl.rcParams["figure.figsize"] = [8, 5]
mpl.rcParams["figure.dpi"] = 120
mpl.rcParams["font.size"] = 14
mpl.rcParams["legend.fontsize"] = 14
mpl.rcParams["figure.titlesize"] = 14


import logging
import numpy as np

# Iterate the loop to read the cell values

env = Environment(latitude = FlightParams.envParams["latitude"], longitude = FlightParams.envParams["longitude"], elevation = FlightParams.envParams["elevation"])

analysis_parameters = {
    # Rocket's dry mass without motor (kg) and its uncertainty (standard deviation)
    "rocket_mass": (FlightParams.spMass, 0), #.001
    # # Rocket's inertia moment perpendicular to its axis (kg*m^2)
    # "rocket_inertia_11": (FlightParams.spCentralDiameter, 0.036),
    # # Rocket's inertia moment relative to its axis (kg*m^2)
    # "rocket_inertia_33": (FlightParams.spCentralAxis, 0.00001),
    # Motors's dry mass without propellant (kg) and its uncertainty (standard deviation)
    "motor_dry_mass": (FlightParams.dryMotorMass, 0), #.001
    # # Motor's dry inertia moment perpendicular to its axis (kg*m^2)
    # "motor_inertia_11": (FlightParams.motor_11_inertia, 0.016),
    # # Motors's dry inertia moment relative to its axis (kg*m^2)
    # "motor_inertia_33": (FlightParams.motor_33_inertia, 0.00001),\
    # Distance between rocket's center of dry mass and motor's center of dry mass (m)
    # THIS is likely wrong, go back to check it

    "motor_dry_mass_position": (np.abs(FlightParams.the_motor_center_of_dry_mass_position - FlightParams.rocket_center_of_dry_mass_position), 0), #.001
    # Motor total impulse (N*s)
    "impulse": (FlightParams.impulse, 0), #25.3

    # "motor_position": (FlightParams.the_motor_position, .01),

    # Motor burn out time (s)
    # "burn_time": (FlightParams.burn_time, .3),
    # Motor's nozzle radius (m)
    "nozzle_radius": (FlightParams.the_nozzle_radius, 0), #.5 / 1000
    # Motor's nozzle throat radius (m)
    "throat_radius": (FlightParams.the_throat_radius, 0), #.5 / 1000
    # Motor's grain separation (axial distance between two grains) (m)
    # "grain_separation": (FlightParams.grainSeparation, 1 / 1000),
    # Motor's grain density (kg/m^3)
    "grain_density": (FlightParams.motor_density, 0), #20
    # Motor's grain outer radius (m)
    # "grain_outer_radius": (FlightParams.grainOuterRadius, 0.3 / 1000),
    # Motor's grain inner radius (m)
    "grain_initial_inner_radius": (FlightParams.grainInnerRadius, 0), #.3 / 1000
    # Motor's grain height (m)
    "grain_initial_height": (FlightParams.grainHeight, 0), #1 / 1000
    # Rocket's radius (kg*m^2)
    # "radius": (FlightParams.spRadius, 0.001),
    # Nozle position relative to motor
    # "nozzle_position": (FlightParams.the_nozzle_position, 0.001),
    # Distance between rocket's center of dry mass and and center of propellant mass (m) (negative)
    "grains_center_of_mass_position": (FlightParams.rocket_center_of_dry_mass_position-(FlightParams.the_motor_center_of_dry_mass_position + FlightParams.the_motor_position), 0), #.0001
    # Axial distance between rocket's center of dry mass and nearest point in its nose cone (m)
    # "nose_distance_to_CM": (FlightParams.rocket_center_of_dry_mass_position-FlightParams.nose_cone_length, 0.001),
    # Launch rail inclination angle relative to the horizontal plane (degrees)
    "inclination": (FlightParams.inclination, 0), #1
    # Launch rail heading relative to north (degrees)
    "heading": (FlightParams.heading, 0), #2
    # Drag coefficient times reference area for the drogue chute (m^2)
    "cd_s_drogue": (FlightParams.drogueCdS, 0), #.02
    # Drag coefficient times reference area for the light chute
    "cd_s_light": (FlightParams.lightCdS, 0), #.02
    # Time delay between parachute ejection signal is detected and parachute is inflated (s)
    "lag_rec": (FlightParams.lag_rec, 0), #.2
    # Time delay between sensor signal is received and ejection signal is fired (s)
    "lag_se": (FlightParams.lag_se, 0), #.1
    # temperature in kelvin
    "temperature": (FlightParams.kelvin_temp, 0), #5
    # atmospheric pressure in pascals
    "atmosphere_pressure": (env.pressure_ISA(FlightParams.envParams["elevation"]), 0), #300

    #without motor
    "rocket_CM": (FlightParams.rocket_center_of_dry_mass_position, 0), #.01

    # adding these, but they don't vary
    "time_to_deploy_airbrake_after_burnout": (-1, 0),
    "fin_position": (2.62, 0)
}

# M1850W.all_info()

#sets up the ability to log inputs.
def setup_logging():
    class MyHandler(logging.FileHandler):
        def emit(self, record):
            super().emit(record)  # Call the superclass's emit method
            self.flush()  # Flush after each log message

    # Use your custom handler
    logger = logging.getLogger()
    logger.setLevel(logging.INFO)
    handler = MyHandler('app.log', 'a')
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)

resultsFile = open(FlightParams.generatedFilesLocation + "results.txt", "w")

def createDistributionPlot(dispersonResultArray, name, lowerProbBound, upperProbBound, maxDecimals, percentConfidence, hypothesis, unit, makeGraph, filename):
    mean = np.mean(dispersonResultArray)
    deviation = np.std(dispersonResultArray)
    unitString = ""
    if(unit == "meters"):
        unitString = "m"
    print(
        f'{name} -         Mean Value: {mean:0.3f} ' + unitString
    )
    resultsFile.write(f'{name} -         Mean Value: {mean:0.3f} ' + unitString + "\n")
    print(
        f'{name} - Standard Deviation: {deviation:0.3f} m' + unitString
    )
    resultsFile.write(f'{name} - Standard Deviation: {deviation:0.3f} m' + unitString + "\n")
    if(makeGraph):

        minimum = np.min(dispersonResultArray)
        maximum = np.max(dispersonResultArray)
        theBins = list()

        #using scott's rule to find the number of bins
        binWidth = 3.5 * deviation / np.power(len(dispersonResultArray), 1/3)
        numBins = int(np.round((maximum-minimum)/binWidth))

        changeInZ = (maximum - minimum) / numBins
        #test add
        zIterator = minimum
        for iterator in range(numBins):
            theBins.append(zIterator)
            zIterator += changeInZ
        finalValue = np.ceil(zIterator * np.power(10, maxDecimals)) / np.power(10, maxDecimals)
        theBins.append(finalValue)
        plt.figure()
        plt.xlim(minimum, maximum)
        minTextSize = 8
        maxTickCount = 50
        xTickBins = theBins
        if(numBins > maxTickCount):
            xTickBins = list()
            changeInZ = (maximum - minimum) / 50.0
            zIterator = minimum
            for iterator in range(50):
                xTickBins.append(zIterator)
                zIterator += changeInZ
        binListToString = list()
        for currentBin in xTickBins:
            binListToString.append(str(round(currentBin, maxDecimals)))
        plt.xticks(ticks = xTickBins, labels = binListToString, rotation = 75, fontsize = minTextSize)
        plt.hist(dispersonResultArray, bins=theBins)
        plt.title(name)
        plt.xlabel(name)
        plt.ylabel("Number of Occurences")

        plt.axvline(mean, color='k', linestyle='solid', linewidth=4)
        plt.axvline(mean - deviation, color='g', linestyle='solid', linewidth=3)
        plt.axvline(mean - 2*deviation, color='g', linestyle='solid', linewidth=3)
        plt.axvline(mean - 3*deviation, color='g', linestyle='solid', linewidth=3)
        plt.axvline(mean + deviation, color='g', linestyle='solid', linewidth=3)
        plt.axvline(mean + 2*deviation, color='g', linestyle='solid', linewidth=3)
        plt.axvline(mean + 3*deviation, color='g', linestyle='solid', linewidth=3)
        plt.savefig(FlightParams.generatedFilesLocation + str(filename) + "Graph.png", bbox_inches="tight", pad_inches=0)
        plt.show()
    lowerZ = (lowerProbBound - mean)/deviation
    upperZ = (upperProbBound - mean)/deviation
    probabilityInRange = norm.cdf(upperZ) - norm.cdf(lowerZ)
    print("PROBABILITY THE " + name +  " IS IN BETWEEN " + str(round(lowerProbBound, 4)) + " AND " + str(round(upperProbBound, 4)) + " IS: " + str(round(probabilityInRange * 100, 2)) + "%")
    resultsFile.write("PROBABILITY THE " + name +  " IS IN BETWEEN " + str(round(lowerProbBound, 4)) + " AND " + str(round(upperProbBound, 4)) + " IS: " + str(round(probabilityInRange * 100, 2)) + "%\n")
    if(percentConfidence != 100):
        aVal = (100 - percentConfidence)/100
        newZ = np.abs(norm.ppf(aVal/2))
        lowerBoundOfInterval = mean - newZ * deviation/np.sqrt(len(dispersonResultArray))
        upperBoundOfInterval = mean + newZ * deviation/np.sqrt(len(dispersonResultArray))
        print("There is a " + str(percentConfidence) + f"% chance that the mean of the " + name + 
              " falls within THIS RANGE: " + str(lowerBoundOfInterval) + ", " + str(upperBoundOfInterval))
        resultsFile.write("There is a " + str(percentConfidence) + f"% chance that the mean of the " + name + 
              " falls within THIS RANGE: " + str(lowerBoundOfInterval) + ", " + str(upperBoundOfInterval) + "\n")
        if(hypothesis != None):
            criticalValue = norm.ppf(aVal / 2)
            testStatistic = (mean - hypothesis) * np.sqrt(len(dispersonResultArray))/deviation
            print("\nWe have the hypothesis that our mean is greater than or equal to " + str(hypothesis) + ". With our critical percent, our critical value is " +
                str(criticalValue) + ". Then, our test statistic is " + str(testStatistic))
            resultsFile.write("\nWe have the hypothesis that our mean is greater than or equal to " + str(hypothesis) + ". With our critical percent, our critical value is " +
                str(criticalValue) + ". Then, our test statistic is " + str(testStatistic) + "\n")
            if(testStatistic < criticalValue):
                print("Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is " + str(hypothesis) + ".\n")
                resultsFile.write("Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is " + str(hypothesis) + ".\n\n")
            else:
                print("Since our test statistic is less extreme than our critical value, we can NOT reject the null hypothesis that the mean is " + str(hypothesis) + ".\n")
                resultsFile.write("Since our test statistic is less extreme than our critical value, we can NOT reject the null hypothesis that the mean is " + str(hypothesis) + ".\n\n")

# envParams["file"] = row[0].value

print("TOTAL SIMS IS: " + str(FlightParams.numberSims))
resultsFile.write("TOTAL SIMS IS: " + str(FlightParams.numberSims) + "\n\n\n")

varyingParamVals = []
apogeeAtIteration = []
currentVal = -1
endVal = -1
incrementAmount = -1
if(FlightParams.varyingVariable == "airbrake"):   
    currentVal = 1
    endVal = 21
    incrementAmount = 1
elif (FlightParams.varyingVariable == "finposition"):
    currentVal = 2.55
    endVal = 2.62
    incrementAmount = 0.005
elif (FlightParams.varyingVariable == "weatherHour"):
    currentVal = 0
    endVal = 23
    incrementAmount = 1

#range only accepts integer values, so for now we make them integers and divide them later
while(True):
    if(FlightParams.varyingVariable == "airbrake"):
        print("THIS IS WHERE WE DEPLOY AIRBRAKE " + str(currentVal) + " SECONDS AFTER BURNOUT")
        resultsFile.write("THIS IS WHERE WE DEPLOY AIRBRAKE " + str(currentVal) + " SECONDS AFTER BURNOUT\n")
        analysis_parameters["time_to_deploy_airbrake_after_burnout"] = (currentVal, 0)
        varyingParamVals.append(currentVal)
    elif(FlightParams.varyingVariable == "finposition"):
        print("CURRENT FIN POSITION IS " + str(currentVal))
        resultsFile.write("CURRENT FIN POSITION IS " + str(currentVal) + "\n")
        analysis_parameters["fin_position"] = (currentVal, 0)
        varyingParamVals.append(currentVal)
    elif(FlightParams.varyingVariable == "weatherHour"):
        wind = getAverageWindPerWeekFromHour(currentVal)
        print("CURRENT HOUR IS " + str(currentVal))
        resultsFile.write("CURRENT HOUR IS " + str(currentVal) + "\n")
        varyingParamVals.append(currentVal)

    setup_logging()
    # env.all_info()
    # Create data files for inputs, outputs and error logging
    filename = "MonteCarlo" + str(currentVal)
    MonteCarloErrorFile = open("CreatedFiles/" + str(filename) + ".Errors.txt", "w")
    MonteCarloInputFile = open("CreatedFiles/" + str(filename) + ".Input.txt", "w")
    MonteCarloOutputFile = open("CreatedFiles/" + str(filename) + ".Output.txt", "w")

    initial_wall_time = time()
    initial_cpu_time = process_time()
    # Iterate over flight settings
    out = display("Starting", display_id=True)
    number_of_simulations = FlightParams.numberSims
    totalProcesses = FlightParams.processes
    simsPerProcess = number_of_simulations / totalProcesses

    # start multiprocessing
    if __name__ == "__main__":
        with concurrent.futures.ProcessPoolExecutor(max_workers=totalProcesses) as executor:
            results = [executor.submit(runFlightWithMonteCarlo, simsPerProcess, FlightParams.envParams, analysis_parameters, initial_cpu_time, False, wind) for _ in range(totalProcesses)] 
            for result in concurrent.futures.as_completed(results):
                MonteCarloInputFile.write(result.result()[0] + "\n")
                MonteCarloOutputFile.write(result.result()[1] + "\n")
                MonteCarloErrorFile.write(result.result()[2] + "\n")

    ## Print and save total time
    final_string = f"Completed {number_of_simulations} iterations successfully. Total CPU time: {process_time() - initial_cpu_time} s. Total wall time: {time() - initial_wall_time} s"
    resultsFile.write(f"Completed {number_of_simulations} iterations successfully. Total CPU time: {process_time() - initial_cpu_time} s. Total wall time: {time() - initial_wall_time} s\n")
    out.update(final_string)
    MonteCarloInputFile.write(final_string + "\n")
    MonteCarloOutputFile.write(final_string + "\n")
    MonteCarloErrorFile.write(final_string + "\n")

    ## Close files
    MonteCarloInputFile.close()
    MonteCarloOutputFile.close()
    MonteCarloErrorFile.close()

    # Initialize variable to store all results
    dispersion_general_results = []

    dispersion_results = {
        "out_of_rail_time": [],
        "out_of_rail_velocity": [],
        "apogee_time": [],
        "apogee_altitude": [],
        "apogee_x": [],
        "apogee_y": [],
        "impact_x": [],
        "impact_y": [],
        "initial_static_margin": [],
        "out_of_rail_static_margin": [],
        "out_of_rail_stability_margin": [],
        "max_velocity": [],
        "execution_time": [],
    }

    # Get all dispersion results
    # Get file
    dispersion_output_file = open("CreatedFiles/" + str(filename) + ".Output.txt", "r+")

    # Read each line of the file and convert to dict
    for line in dispersion_output_file:
        # Skip comments lines
        if line[0] != "{":
            continue
        # Eval results and store them
        flight_result = eval(line)
        dispersion_general_results.append(flight_result)
        for parameter_key, parameter_value in flight_result.items():
            dispersion_results[parameter_key].append(parameter_value)

    # Close data file
    dispersion_output_file.close()

    # Print number of flights simulated
    N = len(dispersion_general_results)
    print("Number of simulations: ", N)
    resultsFile.write("Number of simulations: " + str(N) + "\n")

    # Retrieve dispersion data por apogee and impact XY position
    apogee_x = np.array(dispersion_results["apogee_x"])
    apogee_y = np.array(dispersion_results["apogee_y"])

    createDistributionPlot(dispersion_results["out_of_rail_stability_margin"], "Out Of Rail Stability Margin", lowerProbBound = 1.5, upperProbBound = 4, maxDecimals = 4, percentConfidence = 90, hypothesis = None, unit = "none", makeGraph = False, filename = "Rail" + str(currentVal))
    print("\n\n")
    resultsFile.write("\n\n")
    createDistributionPlot(dispersion_results["apogee_altitude"], "Apogee Altitude", lowerProbBound = 9900 * 0.3048, upperProbBound = 10100 * 0.3048, maxDecimals = 0, percentConfidence = 90, hypothesis = 3048, unit = "meter", makeGraph = True, filename = "Apogee" + str(currentVal))
    print("\n\n\n----------------------------------------------------------------------------------------------------\n\n\n")
    resultsFile.write("\n\n\n----------------------------------------------------------------------------------------------------\n\n\n")
    apogeeAtIteration.append(np.mean(dispersion_results["apogee_altitude"]))

    #img = imread("background.jpeg")

    # Retrieve dispersion data por apogee and impact XY position
    impact_x = np.array(dispersion_results["impact_x"])
    impact_y = np.array(dispersion_results["impact_y"])

    print(f"Simulated Landing Position x = {np.mean(dispersion_results['impact_x'])}, y = {np.mean(dispersion_results['impact_y'])}")
    resultsFile.write(f"Simulated Landing Position x = {np.mean(dispersion_results['impact_x'])}, y = {np.mean(dispersion_results['impact_y'])}\n")
    # Define function to calculate eigen values
    def eigsorted(cov):
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        return vals[order], vecs[:, order]


    # Create plot figure
    plt.figure(num=None, figsize=(8, 6), dpi=150, facecolor="w", edgecolor="k")
    ax = plt.subplot(111)

    # Calculate error ellipses for impact
    impactCov = np.cov(impact_x, impact_y)
    impactVals, impactVecs = eigsorted(impactCov)
    impactTheta = np.degrees(np.arctan2(*impactVecs[:, 0][::-1]))
    impactW, impactH = 2 * np.sqrt(impactVals)

    # Draw error ellipses for impact
    impact_ellipses = []
    for j in [1, 2, 3]:
        impactEll = Ellipse(
            xy=(np.mean(impact_x), np.mean(impact_y)),
            width=impactW * j,
            height=impactH * j,
            angle=impactTheta,
            color="black",
        )
        impactEll.set_facecolor((0, 0, 1, 0.2))
        impact_ellipses.append(impactEll)
        ax.add_artist(impactEll)

    # Calculate error ellipses for apogee
    apogeeCov = np.cov(apogee_x, apogee_y)
    apogeeVals, apogeeVecs = eigsorted(apogeeCov)
    apogeeTheta = np.degrees(np.arctan2(*apogeeVecs[:, 0][::-1]))
    apogeeW, apogeeH = 2 * np.sqrt(apogeeVals)

    # Draw error ellipses for apogee
    for j in [1, 2, 3]:
        apogeeEll = Ellipse(
            xy=(np.mean(apogee_x), np.mean(apogee_y)),
            width=apogeeW * j,
            height=apogeeH * j,
            angle=apogeeTheta,
            color="black",
        )
        apogeeEll.set_facecolor((0, 1, 0, 0.2))
        ax.add_artist(apogeeEll)

    # Draw launch point
    plt.scatter(0, 0, s=30, marker="*", color="black", label="Launch Point")
    # Draw apogee points
    plt.scatter(
        apogee_x, apogee_y, s=5, marker="^", color="green", label="Simulated Apogee"
    )
    # Draw impact points
    plt.scatter(
        impact_x, impact_y, s=5, marker="v", color="blue", label="Simulated Landing Point"
    )

    plt.legend()

    # Add title and labels to plot
    ax.set_title(
        "1$\sigma$, 2$\sigma$ and 3$\sigma$ Dispersion Ellipses: Apogee and Lading Points"
    )
    ax.set_ylabel("North (m)")
    ax.set_xlabel("East (m)")

    # Add background image to plot
    # You can translate the basemap by changing dx and dy (in meters)
    dx = 0
    dy = 0
    #plt.imshow(img, zorder=0, extent=[-1000 - dx, 1000 - dx, -1000 - dy, 1000 - dy])

    plt.axhline(0, color="black", linewidth=0.5)
    plt.axvline(0, color="black", linewidth=0.5)
    plt.xlim(-5000, 5000)
    plt.ylim(-5000, 5000)

    # Save plot and show result
    plt.savefig("CreatedFiles/" + str(filename) + ".pdf", bbox_inches="tight", pad_inches=0)
    plt.savefig("CreatedFiles/" + str(filename) + ".svg", bbox_inches="tight", pad_inches=0)
    plt.show()
    print("\n\n\n----------------------------------------------------------------------------------------------------\n\n\n")
    resultsFile.write("\n\n\n----------------------------------------------------------------------------------------------------\n\n\n")

    currentVal += incrementAmount
    currentVal = round(currentVal, 5 )
    if(currentVal > endVal):
        break

plt.scatter(varyingParamVals, apogeeAtIteration)
if(FlightParams.varyingVariable == "airbrake"):
    plt.title("Apogees at Different Deployment Times")
    plt.xlabel("Airbrake Deployment Time (Seconds after Burnout)")
    plt.ylabel("Apogee for that Time")
elif(FlightParams.varyingVariable == "finposition"):
    plt.title("Apogees at Different Fin Positions")
    plt.xlabel("Fin Position")
    plt.ylabel("Apogee for that Position")
elif(FlightParams.varyingVariable == "weatherHour"):
    plt.title(f"Apogees for Different Hours")
    plt.xlabel("Hour (Military Time)")
    plt.ylabel("Apogee at that hour")
    plt.axhline(3048, color='k', linestyle='solid', linewidth=4)
    
    
#creating the trendline with the given x and y values
trendline = np.polyfit(varyingParamVals, apogeeAtIteration, 1)
trendline = np.poly1d(trendline)
# obtaining the y values from the trendline
y_vals = trendline(varyingParamVals)

# R^2 calculation
residuals = apogeeAtIteration - y_vals
ss_res = np.sum(residuals**2)
ss_tot = np.sum((apogeeAtIteration - np.mean(apogeeAtIteration))**2)
r_squared = 1 - (ss_res / ss_tot)

#plotting the trendline
plt.plot(varyingParamVals, y_vals, "r", label="Trendline (R² = " + str(round(r_squared, 3)) + ")")
plt.legend()

plt.savefig(FlightParams.generatedFilesLocation + f"FinalSimTable{day}.png", bbox_inches="tight", pad_inches=0)
plt.show()
resultsFile.close()
# Out:
# TOTAL SIMS IS: 1
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 0
# 'Completed 1 iterations successfully. Total CPU time: 0.109375 s. Total wall time: 6.574494361877441 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.552
# Out Of Rail Stability Margin - Standard Deviation: 0.044 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 87.81%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5285899593035894, 1.5746564691175629
#
#
#
# Apogee Altitude -         Mean Value: 2920.229
# Apogee Altitude - Standard Deviation: 41.841 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 1.0%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2898.465583119028, 2941.992993072969
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -9.6566333313127
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 125.58210465808438, y = 1742.1840302492433
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 1
# 'Completed 1 iterations successfully. Total CPU time: 0.03125 s. Total wall time: 6.652228832244873 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.532
# Out Of Rail Stability Margin - Standard Deviation: 0.030 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 85.57%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5163374711962805, 1.547760901700918
#
#
#
# Apogee Altitude -         Mean Value: 2955.339
# Apogee Altitude - Standard Deviation: 20.182 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 0.1%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2944.841705205717, 2965.837145877413
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -14.518683780600924
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 1424.9100338540463, y = 1166.436403810597
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 2
# 'Completed 1 iterations successfully. Total CPU time: 0.0 s. Total wall time: 6.867910623550415 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.572
# Out Of Rail Stability Margin - Standard Deviation: 0.030 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 99.27%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5570291553814302, 1.5879121625506756
#
#
#
# Apogee Altitude -         Mean Value: 2971.405
# Apogee Altitude - Standard Deviation: 27.264 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 4.53%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2957.2234939781015, 2985.586442931693
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -8.883957422732768
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 290.73944438397086, y = 640.3845825902403
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 3
# 'Completed 1 iterations successfully. Total CPU time: 0.03125 s. Total wall time: 7.870559930801392 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.567
# Out Of Rail Stability Margin - Standard Deviation: 0.046 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 92.77%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5428519225674473, 1.5903422925246364
#
#
#
# Apogee Altitude -         Mean Value: 2967.217
# Apogee Altitude - Standard Deviation: 35.158 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 7.55%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2948.929999499737, 2985.5044454480444
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -7.2660482565796505
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 156.18719147561922, y = 196.6097521617582
# C:\Users\mahd\AppData\Local\Temp\ipykernel_12188\1957429873.py:377: RuntimeWarning: invalid value encountered in sqrt
#   impactW, impactH = 2 * np.sqrt(impactVals)
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 4
# 'Completed 1 iterations successfully. Total CPU time: 0.015625 s. Total wall time: 7.7304465770721436 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.576
# Out Of Rail Stability Margin - Standard Deviation: 0.029 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 99.62%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5616033094127273, 1.5913877671620713
#
#
#
# Apogee Altitude -         Mean Value: 2990.379
# Apogee Altitude - Standard Deviation: 14.662 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 3.21%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2982.7528095715256, 2998.005912830195
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -12.427309395175962
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 5
# 'Completed 1 iterations successfully. Total CPU time: 0.078125 s. Total wall time: 8.772043704986572 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.556
# Out Of Rail Stability Margin - Standard Deviation: 0.049 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 87.46%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.530718273830325, 1.5815901386560112
#
#
#
# Apogee Altitude -         Mean Value: 3009.639
# Apogee Altitude - Standard Deviation: 32.796 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 38.71%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2992.580153490191, 3026.697617561411
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -3.6988926342866804
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 6
# 'Completed 1 iterations successfully. Total CPU time: 0.03125 s. Total wall time: 8.281378269195557 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.564
# Out Of Rail Stability Margin - Standard Deviation: 0.050 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 90.05%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5380637034500968, 1.5898626864353578
#
#
#
# Apogee Altitude -         Mean Value: 3014.984
# Apogee Altitude - Standard Deviation: 19.107 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 44.68%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 3005.045107435211, 3024.9221478018158
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -5.464304429517426
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 7
# 'Completed 1 iterations successfully. Total CPU time: 0.078125 s. Total wall time: 8.260118007659912 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.523
# Out Of Rail Stability Margin - Standard Deviation: 0.032 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 76.3%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5062868847479278, 1.539686554278059
#
#
#
# Apogee Altitude -         Mean Value: 2979.171
# Apogee Altitude - Standard Deviation: 23.291 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 4.98%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2967.056461519453, 2991.28578132588
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -9.345159622425706
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 8
# 'Completed 1 iterations successfully. Total CPU time: 0.015625 s. Total wall time: 8.148453712463379 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.572
# Out Of Rail Stability Margin - Standard Deviation: 0.041 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 95.96%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5506250168206979, 1.593568788624995
#
#
#
# Apogee Altitude -         Mean Value: 2988.172
# Apogee Altitude - Standard Deviation: 31.793 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 17.57%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2971.6347524143243, 3004.709103029481
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -5.950739461233577
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 9
# 'Completed 1 iterations successfully. Total CPU time: 0.0625 s. Total wall time: 8.565942287445068 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.574
# Out Of Rail Stability Margin - Standard Deviation: 0.046 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 94.54%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5500532198002726, 1.5981890447353002
#
#
#
# Apogee Altitude -         Mean Value: 3019.815
# Apogee Altitude - Standard Deviation: 20.157 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 54.35%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 3009.330140472154, 3030.299899528525
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -4.421621293155577
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 10
# 'Completed 1 iterations successfully. Total CPU time: 0.046875 s. Total wall time: 8.64424467086792 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.532
# Out Of Rail Stability Margin - Standard Deviation: 0.034 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 82.11%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.513732718029088, 1.5495117115574655
#
#
#
# Apogee Altitude -         Mean Value: 3030.990
# Apogee Altitude - Standard Deviation: 31.747 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 59.7%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 3014.4765144036933, 3047.503326900371
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -1.6943258277226356
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 11
# 'Completed 1 iterations successfully. Total CPU time: 0.078125 s. Total wall time: 8.147217035293579 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.584
# Out Of Rail Stability Margin - Standard Deviation: 0.062 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 91.29%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.551943768051753, 1.616396203543366
#
#
#
# Apogee Altitude -         Mean Value: 3023.912
# Apogee Altitude - Standard Deviation: 29.641 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 55.26%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 3008.4944532452205, 3039.329851989912
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -2.569837572752051
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 0.0, y = 0.0
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 12
# 'Completed 1 iterations successfully. Total CPU time: 0.046875 s. Total wall time: 8.890352010726929 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.554
# Out Of Rail Stability Margin - Standard Deviation: 0.033 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 94.85%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.536949977170783, 1.5715735789036278
#
#
#
# Apogee Altitude -         Mean Value: 2989.892
# Apogee Altitude - Standard Deviation: 33.347 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 19.98%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2972.5468461890623, 3007.2378670588287
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -5.510277043706434
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 228.27380413429114, y = 811.8513017536409
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 13
# 'Completed 1 iterations successfully. Total CPU time: 0.046875 s. Total wall time: 8.040233135223389 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.565
# Out Of Rail Stability Margin - Standard Deviation: 0.039 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 95.16%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.544402134711995, 1.5849124149240323
#
#
#
# Apogee Altitude -         Mean Value: 2969.952
# Apogee Altitude - Standard Deviation: 24.238 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 2.48%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2957.3442266586767, 2982.559339985511
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -10.182614737100886
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 80.46128638231619, y = 280.20277588575703
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 14
# 'Completed 1 iterations successfully. Total CPU time: 0.109375 s. Total wall time: 9.05372166633606 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.569
# Out Of Rail Stability Margin - Standard Deviation: 0.059 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 87.99%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5382996813551268, 1.5991874433049396
#
#
#
# Apogee Altitude -         Mean Value: 2975.238
# Apogee Altitude - Standard Deviation: 25.666 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 4.97%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2961.8874471741983, 2988.588171944357
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -8.964786827443605
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 87.7318895281373, y = 297.5975629894966
# C:\Users\mahd\AppData\Local\Temp\ipykernel_12188\1957429873.py:377: RuntimeWarning: invalid value encountered in sqrt
#   impactW, impactH = 2 * np.sqrt(impactVals)
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 15
# 'Completed 1 iterations successfully. Total CPU time: 0.078125 s. Total wall time: 7.910498380661011 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.585
# Out Of Rail Stability Margin - Standard Deviation: 0.041 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 98.16%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5639417114335534, 1.6063668635465873
#
#
#
# Apogee Altitude -         Mean Value: 2961.757
# Apogee Altitude - Standard Deviation: 36.347 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 6.18%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2942.851443361108, 2980.6626831275653
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -7.503430630557736
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 115.48259634175909, y = 294.66533740464587
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 16
# 'Completed 1 iterations successfully. Total CPU time: 0.015625 s. Total wall time: 8.528182744979858 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.572
# Out Of Rail Stability Margin - Standard Deviation: 0.055 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 90.29%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5431277393087162, 1.6007832818563341
#
#
#
# Apogee Altitude -         Mean Value: 2973.683
# Apogee Altitude - Standard Deviation: 45.256 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 15.61%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2950.142770456433, 2997.222959199753
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -5.192876774500932
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 492.35797851254904, y = 1203.383969864015
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 17
# 'Completed 1 iterations successfully. Total CPU time: 0.015625 s. Total wall time: 8.011734008789062 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.560
# Out Of Rail Stability Margin - Standard Deviation: 0.050 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 88.47%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.534072469138254, 1.586298803335944
#
#
#
# Apogee Altitude -         Mean Value: 2965.141
# Apogee Altitude - Standard Deviation: 28.314 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 3.21%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2950.4133552551184, 2979.8683255001233
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -9.254206546288058
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 318.25479637938105, y = 569.4024652218968
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 18
# 'Completed 1 iterations successfully. Total CPU time: 0.078125 s. Total wall time: 8.016916036605835 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.563
# Out Of Rail Stability Margin - Standard Deviation: 0.034 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 96.97%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5455496037542606, 1.5804777570345778
#
#
#
# Apogee Altitude -         Mean Value: 2960.195
# Apogee Altitude - Standard Deviation: 33.725 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 4.44%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2942.653013536752, 2977.7371406473803
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -8.233138903749818
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 704.927888894731, y = 784.8113055551255
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 19
# 'Completed 1 iterations successfully. Total CPU time: 0.03125 s. Total wall time: 8.654042482376099 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.552
# Out Of Rail Stability Margin - Standard Deviation: 0.050 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 85.15%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5259085324613213, 1.577448617403958
#
#
#
# Apogee Altitude -         Mean Value: 2965.208
# Apogee Altitude - Standard Deviation: 27.483 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 2.85%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2950.913095072837, 2979.503173911205
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -9.526416560987025
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 1020.4156070362718, y = 1287.2874370488269
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 20
# 'Completed 1 iterations successfully. Total CPU time: 0.015625 s. Total wall time: 8.178614139556885 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.557
# Out Of Rail Stability Margin - Standard Deviation: 0.051 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 86.85%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5305004983682098, 1.5834731355447795
#
#
#
# Apogee Altitude -         Mean Value: 2940.347
# Apogee Altitude - Standard Deviation: 45.208 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 4.28%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2916.832242475495, 2963.862026903442
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -7.530258031653762
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 1124.4822464092247, y = 1207.3085364676049
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 21
# 'Completed 1 iterations successfully. Total CPU time: 0.078125 s. Total wall time: 9.227458477020264 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.540
# Out Of Rail Stability Margin - Standard Deviation: 0.034 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 87.6%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5218642848426849, 1.557680231258244
#
#
#
# Apogee Altitude -         Mean Value: 2943.354
# Apogee Altitude - Standard Deviation: 35.202 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 1.75%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2925.0439753535957, 2961.664675773648
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -9.40052020671942
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 540.9731074734342, y = 2064.8012649718858
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 22
# 'Completed 1 iterations successfully. Total CPU time: 0.0625 s. Total wall time: 8.197317123413086 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.577
# Out Of Rail Stability Margin - Standard Deviation: 0.033 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 99.07%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5599449055893027, 1.5939714668691598
#
#
#
# Apogee Altitude -         Mean Value: 2941.561
# Apogee Altitude - Standard Deviation: 38.699 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 2.46%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2921.43155536526, 2961.690210491424
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -8.697596440624652
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 1225.511114163312, y = 2234.270595130856
# ----------------------------------------------------------------------------------------------------
#
#
#
# date: 2025-06-04
# date: 2025-06-03
# date: 2025-06-02
# date: 2025-06-01
# date: 2025-05-31
# date: 2025-05-30
# date: 2025-05-29
# CURRENT HOUR IS 23
# 'Completed 1 iterations successfully. Total CPU time: 0.046875 s. Total wall time: 8.289786577224731 s'
# Number of simulations:  10
# Out Of Rail Stability Margin -         Mean Value: 1.556
# Out Of Rail Stability Margin - Standard Deviation: 0.038 m
# PROBABILITY THE Out Of Rail Stability Margin IS IN BETWEEN 1.5 AND 4 IS: 92.68%
# There is a 90% chance that the mean of the Out Of Rail Stability Margin falls within THIS RANGE: 1.5357885418315276, 1.575715351313909
#
#
#
# Apogee Altitude -         Mean Value: 2956.376
# Apogee Altitude - Standard Deviation: 16.723 m
# PROBABILITY THE Apogee Altitude IS IN BETWEEN 3017.52 AND 3078.48 IS: 0.01%
# There is a 90% chance that the mean of the Apogee Altitude falls within THIS RANGE: 2947.6778938854754, 2965.074325844645
#
# We have the hypothesis that our mean is greater than or equal to 3048. With our critical percent, our critical value is -1.6448536269514729. Then, our test statistic is -17.32629867522018
# Since our test statistic is more extreme than our critical value, we can reject the null hypothesis that the mean is 3048.
#
#
#
#
# ----------------------------------------------------------------------------------------------------
#
#
#
# Simulated Landing Position x = 910.4960817672751, y = 1248.497972537856
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 484
#     481 plt.plot(varyingParamVals, y_vals, "r", label="Trendline (R² = " + str(round(r_squared, 3)) + ")")
#     482 plt.legend()
# --> 484 plt.savefig(FlightParams.generatedFilesLocation + f"FinalSimTable{day}.png", bbox_inches="tight", pad_inches=0)
#     485 plt.show()
#     486 resultsFile.close()
#
# NameError: name 'day' is not defined
